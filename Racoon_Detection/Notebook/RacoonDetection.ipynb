# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

import tensorflow
import tensorflow.keras

import cv2

# %%
label=pd.read_csv("C:\\Users\\hp\\Documents\\MGP\\Racoon_Detection\\Dataset\\train_labels_.csv")
label.head()
# Out:
#          filename  width  height    class  xmin  ymin  xmax  ymax
# 0  raccoon-17.jpg    259     194  raccoon    95    60   167   118
# 1  raccoon-11.jpg    660     432  raccoon     3     1   461   431
# 2  raccoon-63.jpg    600     400  raccoon    74   107   280   290
# 3  raccoon-63.jpg    600     400  raccoon   227    93   403   298
# 4  raccoon-60.jpg    273     185  raccoon    58    33   197   127

# %%
img=cv2.imread("C:\\Users\\hp\\Documents\\MGP\\Racoon_Detection\\Dataset\\Racoon Images\\images\\raccoon-17.jpg")
plt.imshow(img)

# %%
img=cv2.rectangle(img,(label["xmin"].iloc[0],label["ymin"].iloc[0]),(label["xmax"].iloc[0],label["ymax"].iloc[0]),(0,255,0),3)

# %%
plt.imshow(img)
